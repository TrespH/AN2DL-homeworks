# %% [markdown]
# # Import Libraries

# %%
import shutil
import os
import zipfile
import sys
import numpy as np
from sklearn.metrics import accuracy_score

# %% [markdown]
# # 1 - Clear the Extracted Files Directory

# %%
extracted_files_dir = 'extracted_files'
if os.path.exists(extracted_files_dir):
    shutil.rmtree(extracted_files_dir)
os.makedirs(extracted_files_dir)

# %% [markdown]
# # 2 - Extract the zip file

# %%
zip_file_path = 'submission_241119_154751.zip'
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extracted_files_dir)

# %% [markdown]
# # 3 - Load the model

# %%
sys.path.append(extracted_files_dir)
from model import Model
model_instance = Model()
# Out:
# 2024-11-19 15:48:26.837782: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # 4 - Load the dataset

# %%
data = np.load('training_set.npz')
X = data['images'][:100]
y = data['labels'][:100]

# %%
y = y.flatten()

# %% [markdown]
# # 5 - Make predictions

# %%
predictions = model_instance.predict(X)
print(f"Predictions: {predictions}")
print(f"Actual labels: {y}")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732027722.728299 1757745 service.cc:145] XLA service 0x7f80a3217650 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1732027722.728804 1757745 service.cc:153]   StreamExecutor device (0): Host, Default Version
# 2024-11-19 15:48:42.730626: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-19 15:48:42.893664: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# ...

# %% [markdown]
# # 6 - Evaluate the predictions

# %%
accuracy = accuracy_score(y, predictions)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.97
